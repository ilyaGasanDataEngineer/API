# %% [markdown]
# # API

# %% [markdown]
# API aplication programming interface -b это механизмы которые позвыаляют двум программным компонентам взаимодействовать друг с другом используя набор протоколов

# %% [markdown]
# ## что предлагает API

# %% [markdown]
# 1) взаимозаменяеемость
# 2) маштабируемость
# 3) безопасность

# %% [markdown]
# ## Типы API

# %% [markdown]
# 1) публичные (открытыйц бесплатный ) WEB api http protocol
# 2) партнерские (доступен только авторизованным разработчиками)
# 3) внтрение (внутри предприятия)

# %% [markdown]
# # Коды ошибок

# %% [markdown]
# 1) информационные 100-199
# 2) успешные 200 -299
# 3) перенаправление 300-399
# 4) клентские 400-499
# 5) серверные 500-599

# %% [markdown]
# # htttp

# %% [markdown]
# get
# put
# post
# delet

# %% [markdown]
# REST (Representational state transfer) – это стиль архитектуры программного обеспечения для распределенных систем, таких как World Wide Web, который, как правило, используется для построения веб-служб. Термин REST был введен в 2000 году Роем Филдингом, одним из авторов HTTP-протокола. Системы, поддерживающие REST, называются RESTful-системами.
#
# В общем случае REST является очень простым интерфейсом управления информацией без использования каких-то дополнительных внутренних прослоек. Каждая единица информации однозначно определяется глобальным идентификатором, таким как URL. Каждая URL в свою очередь имеет строго заданный формат.
#
# А теперь тоже самое более наглядно:
#
# Отсутствие дополнительных внутренних прослоек означает передачу данных в том же виде, что и сами данные. Т.е. мы не заворачиваем данные в XML, как это делает SOAP и XML-RPC, не используем AMF, как это делает Flash и т.д. Просто отдаем сами данные.
#
# Каждая единица информации однозначно определяется URL – это значит, что URL по сути является первичным ключом для единицы данных. Т.е. например третья книга с книжной полки будет иметь вид /book/3, а 35 страница в этой книге — /book/3/page/35. Отсюда и получается строго заданный формат. Причем совершенно не имеет значения, в каком формате находятся данные по адресу /book/3/page/35 – это может быть и HTML, и отсканированная копия в виде jpeg-файла, и документ Microsoft Word.
#
# Как происходит управление информацией сервиса – это целиком и полностью основывается на протоколе передачи данных. Наиболее распространенный протокол конечно же HTTP. Так вот, для HTTP действие над данными задается с помощью методов: GET (получить), PUT (добавить, заменить), POST (добавить, изменить, удалить), DELETE (удалить). Таким образом, действия CRUD (Create-Read-Updtae-Delete) могут выполняться как со всеми 4-мя методами, так и только с помощью GET и POST.
#
# Вот как это будет выглядеть на примере:
#
# GET /book/ — получить список всех книг
# GET /book/3/ — получить книгу номер 3
# PUT /book/ — добавить книгу (данные в теле запроса)
# POST /book/3 – изменить книгу (данные в теле запроса)
# DELETE /book/3 – удалить книгу

# %% [markdown]
# ## Правила Rest

# %% [markdown]
# 1) Клиент и сервер работают независимо
# 2) сревер не сохраняеи запрросы отправленные клиентом информация хранится  в кеше клиента
# 3) архитектурадолжна быть многоуровневая
# 4) манипуляции с данными зависят исключительно от выбранного протокола
# 5) уникальностть ресукрса и предоставление инструмента для поиска по ним

# %% [markdown]
# # аунтификация api

# %% [markdown]
# 1) apikey
# 2) http basic (header: " base64(username:password")"
# 3) OAUTH 1.0/2.0

# %% [markdown]
# # Swager

# %% [markdown]
# swager позволяет писать документацуию на основе кода

# %% [markdown]
# ## gRPC

# %% [markdown]
# gRPC - система удаленного вызова процедур с открытым кодом REMOTE PRODUCEDURE CALL  Базируется на HTTP 2.0

# %% [markdown]
# 1) оптимизация скорости предаич данных
# 2) небольшое распространекние
# 3) метод на собственном коде
